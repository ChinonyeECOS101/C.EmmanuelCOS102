# %%
# Practice 1 | Cell 1 - Your First Class

class SST:
    prog1 = 'Software Engineering' # class variable

    def __init__(self, name):
        self.name = name # instance variable
    def speak(self):
        print ('\nMy name is', self.name)
        print ('I study', SST.prog1)
stud1 = SST(input('Enter student 1 name: '))
stud2 = SST(input('Enter student 2 name: '))

stud1.speak()
stud2.speak()
# Out:
# Enter student 1 name:  rita
# Enter student 2 name:  yoga
# My name is rita
# I study Software Engineering
#
# My name is yoga
# I study Software Engineering

# %%
class Addition:
    def __init__(self, f, s):
        self.first = f
        self.second = s
        self.answer = None
    
    def calculate (self):
        self.answer = self.first + self.second
        
    def display(self):
        print("\nFirst: ", self.first)
        print("Second: ", self.second)
        print("\nSum: " , self.answer)

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

obj = Addition(num1, num2)
obj.calculate()
obj.display()
# Out:
# Enter first number:  6
# Enter second number:  9
# First:  6
# Second:  9
#
# Sum:  15

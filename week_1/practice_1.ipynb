# %%
# Integer number
num = 100
print(num)
print("Data Type of variable num is", type(num))

# float number 
fnum = 34.45
print(fnum)
print("Data Type of varaible fnum is", type(fnum))

#complex number
cnum = 3 + 4j
print(cnum)
print("Data Type of varaible cnum is", type(cnum))
# Out:
# 100
# Data Type of variable num is <class 'int'>
# 34.45
# Data Type of varaible fnum is <class 'float'>
# (3+4j)
# Data Type of varaible cnum is <class 'complex'>

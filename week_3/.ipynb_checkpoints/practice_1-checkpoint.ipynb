# %%
def printme( str ):
    #this is a printt function 
    print(str);
    return;

printme("I'm first call to user defined function!");
printme("Again second call to the same function");
# Out:
# I'm first call to user defined function!
# Again second call to the same function

# %%
def changeme(mylist):
    #this change a passed list
    mylist.append([1,2,3,4])
    print ("values inside the function: ", mylist)
    return
mylist = [10,20,30]
changeme(mylist)
print ("Values outside the function: ", mylist)
# Out:
# values inside the function:  [10, 20, 30, [1, 2, 3, 4]]
# Values outside the function:  [10, 20, 30, [1, 2, 3, 4]]

# %%
def changeme (alist):
    #this changes a passed list
    mylist = [1,2,3,4]
    print("Values inside the function: ", alist)
    return
alist = [10,20,30]
changeme(alist);
print("Values outside the function: " ,alist)
# Out:
# Values inside the function:  [10, 20, 30]
# Values outside the function:  [10, 20, 30]

# %%
def printme(str):
    #this prints a passed string
    print(str);
    return;
printme("chinonye")
# Out:
# chinonye

# %%
def printme(str):
    # this prints a passed string
    print (str);
    return;
printme(str = "My family")
# Out:
# My family

# %%
def printinfo(name, age):
    #test function
    print ("Name: ", name)
    print("Age:  ", age)
    return;
printinfo(age=50, name="Chinonye")
# Out:
# Name:  Chinonye
# Age:   50

# %%
def printinfo ( age, name="chinaza"):
    # test function
    print("Name: ",name)
    print("Age: ", age)
    return;
printinfo( name="francis",age= 14);
printinfo(age = 12);
printinfo(age= 10, name= "Chioma");
# Out:
# Name:  francis
# Age:  14
# Name:  chinaza
# Age:  12
# Name:  Chioma
# Age:  10

# %%
def printinfo(agr1, *vartuple):
    #this is test
    print ("Output is: ")
    print(agr1)
    for var in vartuple:
        print(var)
        return;
printinfo(10);
printinfo(70, 60, 50);
# Out:
# Output is:
# 10
# Output is:
# 70
# 60

# %%
total = 50;   # this is the gobal variable 
def sum (arg1, arg2):
    #add both the parameters
    total = arg1 +arg2;
    print ("Inside the function local total : ", total)
    return total;
# now you can call sum function 
sum(10, 20);
print ( "Outside the function global total: ", total)
# Out:
# Inside the function local total :  30
# Outside the function global total:  50

# %%
def swap(x,y):
    global a
    a = "Lawal"
    x,y = y,x
    b = "chris"
    b = "Edward"
    c = "Lola"
    print (a, b, c, x, y)
    a= "Mary"
swap("Tina", "Tolu")
print (a)
# Out:
# Lawal Edward Lola tolu tina
# Mary

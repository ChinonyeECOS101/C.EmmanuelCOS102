# %% [markdown]
# START Store_Checkout_Process
#
# // 1. Input Phase
#
# INPUT "Scan the price of the items"
#
# INPUT "Input the prices of the items"
#
# // 2. Processing Phase
#
# COMPUTE "Cost of all the items"
#
# (Total_Cost = Sum of item prices)
#
# // 3. Payment and Packing
#
# PRINT  "Make payment and pack the items"
#
# // 4. Documentation Phase
#
# PRINT "Print and collect receipt"
#
#
# ![Store checkout after purchase.jpg](attachment:c4ac16fd-a07b-434b-94d4-b9e7c8d8c426.jpg)

# %% [markdown]
# ![Diagram.drawio.png](attachment:20c0e5eb-4267-4cc5-8187-eb767a582a28.png)

# %% [markdown]
# INPUT name1
#
# INPUT age1
#
# INPUT name2
#
# INPUTE age2
#
# INPUT a variable to age1
#
# INPUT age1 to age2
#
# INPUT age2 to the variable
#
# PRINT name1
#
# PRINT age1
#
# PRINT name2
#
# PRINT age2

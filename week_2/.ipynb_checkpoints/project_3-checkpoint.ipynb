# %%
import pandas as pd
print("WELCOME TO THE YEAR 11 REGISTER")
print("\n")
data = {
    'NAME': ['Evelyn', 'Jessica', 'Somto', 'Edith', 'Liza', 'Madonna', 'Waje', 'Tola', 'Ashia', 'Latifa', 'Chinedu', 'Liam', 'Wale', 'Gbeng' , 'Abiola', 
             'Kola', 'Kunle', 'George', 'Thomas',
            'Wesley'],
    'AGE': [17, 16, 17, 18, 16, 18, 17, 20, 19, 17,19, 16, 18, 17, 20, 19, 16, 18, 17, 19],
    'HEIGHT': [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5, 5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7],
    'SCORES': [80, 85, 70, 60, 76, 66, 87,95, 50, 49, 74, 87, 75, 68, 66, 78, 87, 98, 54, 60],
    'GENDER': ['F', 'F','F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',]
}
df = pd.DataFrame(data)
print(df)
# Out:
# WELCOME TO THE YEAR 11 REGISTER
#
#
#        NAME  AGE  HEIGHT  SCORES GENDER
# 0    Evelyn   17     5.5      80      F
# 1   Jessica   16     6.0      85      F
# 2     Somto   17     5.4      70      F
# 3     Edith   18     5.9      60      F
# 4      Liza   16     5.6      76      F
# 5   Madonna   18     5.5      66      F
# 6      Waje   17     6.1      87      F
# 7      Tola   20     6.0      95      F
# 8     Ashia   19     5.7      50      F
# 9    Latifa   17     5.5      49      F
# 10  Chinedu   19     5.7      74      M
# 11     Liam   16     5.9      87      M
# 12     Wale   18     5.8      75      M
# 13    Gbeng   17     6.1      68      M
# 14   Abiola   20     5.9      66      M
# 15     Kola   19     5.5      78      M
# 16    Kunle   16     6.1      87      M
# 17   George   18     5.4      98      M
# 18   Thomas   17     5.8      54      M
# 19   Wesley   19     5.7      60      M

# %% [markdown]
# INPUT the library needed in python
#
# INPUT the header
#
# INPUT the name reguired using the library synax
#
# INPUT the age reguired using the library synax
#
# INPUT the height reguired using the library synax
#
# INPUT the score reguired using the library synax
#
# PRINT the output of the data
